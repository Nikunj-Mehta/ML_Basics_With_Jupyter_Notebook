# %%
## Import Libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import joblib # We don't need to train model again and again that's why model persistance is imp. 

# ## Importing Data(CSV)
# music_data = pd.read_csv('music.csv')

# ## Splitting data into input and output 
# X = music_data.drop(columns=['genre'])
# y = music_data['genre']
# ## Split the data into training(70%) and Testing (30%)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# ## Selecting appropriate model
# model = DecisionTreeClassifier()
# ## Train model
# model.fit(X_train, y_train)

# joblib.dump(model, 'music-recommender.joblib') ## Build and train a model once and then save it in a file then just load the saved file

model = joblib.load('music-recommender.joblib')

## Make prediction
# predictions = model.predict(X_test) ## make prediction 1st is 21 year old male, 2nd is 22 y/o female
predictions = model.predict([[21, 1]])
predictions

## Evaluate
# score = accuracy_score(y_test, predictions)
# score
# Out:
# C:\Users\NIKUNJ MEHTA\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['HipHop'], dtype=object)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

music_data = pd.read_csv('music.csv')
X = music_data.drop(columns=['genre'])
y = music_data['genre']

# Create the model
model = DecisionTreeClassifier()
model.fit(X, y)

# Export decision tree to .dot file
tree.export_graphviz(
    model,
    out_file='music-recommender.dot',
    feature_names=['age', 'gender'],
    class_names=sorted(y.unique()),
    label='all',
    rounded=True,
    filled=True
)
